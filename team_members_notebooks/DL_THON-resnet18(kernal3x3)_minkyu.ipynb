# %%
import tensorflow as tf
import numpy as np
from PIL import Image
import glob
import os

# %%
#데이터 리사이징 함수구현
def resize_images(img_path):
    images=glob.glob(img_path + "/*.jpg")+ glob.glob(img_path + "/*.JPG")  
    
    print(len(images), " images to be resized.")

    # 파일마다 모두 224x224 사이즈로 바꾸어 저장합니다.
    target_size=(224,224)
    for img in images:
        old_img=Image.open(img)
        new_img=old_img.resize(target_size,Image.ANTIALIAS)
        new_img.save(img, "JPEG")
    
    print(len(images), " images resized.")
    return images

# Moon_jellyfish 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
img_path = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','Train','Moon_jellyfish')
resize_images(img_path)

print("Moon_jellyfish 이미지 resize 완료!")
# Out:
# 150  images to be resized.
# 150  images resized.
# Moon_jellyfish 이미지 resize 완료!

# %%
#데이터 리사이징 함수구현
def resize_images(img_path):
    images=glob.glob(img_path + "/*.jpg")  + glob.glob(img_path + "/*.JPG")
    
    print(len(images), " images to be resized.")

    # 파일마다 모두 224x224 사이즈로 바꾸어 저장합니다.
    target_size=(224,224)
    for img in images:
        old_img=Image.open(img)
        new_img=old_img.resize(target_size,Image.ANTIALIAS)
        new_img.save(img, "JPEG")
    
    print(len(images), " images resized.")
    return images

# mauve_stinger_jellyfish 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
img_path = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','Train','mauve_stinger_jellyfish')
resize_images(img_path)

print("mauve_stinger_jellyfish 이미지 resize 완료!")
# Out:
# 150  images to be resized.
# 150  images resized.
# mauve_stinger_jellyfish 이미지 resize 완료!

# %%
#데이터 리사이징 함수구현
def resize_images(img_path):
    images=glob.glob(img_path + "/*.jpg")  + glob.glob(img_path + "/*.JPG")+ glob.glob(img_path + "/*.jpeg")+ glob.glob(img_path + "/*.png")
    
    print(len(images), " images to be resized.")

    # 파일마다 모두 224x224 사이즈로 바꾸어 저장합니다.
    target_size=(224,224)
    for img in images:
        old_img=Image.open(img)
        new_img=old_img.resize(target_size,Image.ANTIALIAS)
        new_img.save(img, "JPEG")
    
    print(len(images), " images resized.")
    return images

# lions_mane_jellyfish 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
img_path = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','Train','lions_mane_jellyfish')
resize_images(img_path)

print("lions_mane_jellyfish 이미지 resize 완료!")
# Out:
# 150  images to be resized.
# 150  images resized.
# lions_mane_jellyfish 이미지 resize 완료!

# %%
#데이터 리사이징 함수구현
def resize_images(img_path):
    images=glob.glob(img_path + "/*.jpg")  + glob.glob(img_path + "/*.JPG")+glob.glob(img_path + "/*.jpeg")
    
    print(len(images), " images to be resized.")

    # 파일마다 모두 224x224 사이즈로 바꾸어 저장합니다.
    target_size=(224,224)
    for img in images:
        old_img=Image.open(img)
        new_img=old_img.resize(target_size,Image.ANTIALIAS)
        new_img.save(img, "JPEG")
    
    print(len(images), " images resized.")
    return images

# compass_jellyfish 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
img_path = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','Train','compass_jellyfish')
resize_images(img_path)

print("compass_jellyfish 이미지 resize 완료!")
# Out:
# 150  images to be resized.
# 150  images resized.
# compass_jellyfish 이미지 resize 완료!

# %%
#데이터 리사이징 함수구현
def resize_images(img_path):
    images=glob.glob(img_path + "/*.jpg")  + glob.glob(img_path + "/*.JPG")+glob.glob(img_path + "/*.jpeg")+ glob.glob(img_path + "/*.png")
    
    print(len(images), " images to be resized.")

    # 파일마다 모두 224x224 사이즈로 바꾸어 저장합니다.
    target_size=(224,224)
    for img in images:
        old_img=Image.open(img)
        new_img=old_img.resize(target_size,Image.ANTIALIAS)
        new_img.save(img, "JPEG")
    
    print(len(images), " images resized.")
    return images

# blue_jellyfish 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
img_path = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','Train','blue_jellyfish')
resize_images(img_path)

print("blue_jellyfish 이미지 resize 완료!")
# Out:
# 150  images to be resized.
# 150  images resized.
# blue_jellyfish 이미지 resize 완료!

# %%
#데이터 리사이징 함수구현
def resize_images(img_path):
    images=glob.glob(img_path + "/*")#이렇게 전체를 불러와도된다.위에서는 이미지말고 다른데이터가있을경우 확장자를 지정해서 불러오는 방법이다.
    
    print(len(images), " images to be resized.")

    # 파일마다 모두 224x224 사이즈로 바꾸어 저장합니다.
    target_size=(224,224)
    for img in images:
        old_img=Image.open(img)
        new_img=old_img.resize(target_size,Image.ANTIALIAS)
        new_img.save(img, "JPEG")
    
    print(len(images), " images resized.")
    return images

# barrel_jellyfish 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
img_path = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','Train','barrel_jellyfish')
resize_images(img_path)

print("barrel_jellyfish 이미지 resize 완료!")
# Out:
# 150  images to be resized.
# 150  images resized.
# barrel_jellyfish 이미지 resize 완료!

# %%
# #전체 학습데이터 개수
total_images = 900
print(f"전체 이미지 개수: {total_images}")
# Out:
# 전체 이미지 개수: 900

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
from PIL import Image
import glob
import os
from sklearn.model_selection import train_test_split

# %%
#바뀐 jellyfishes 의 데이터300개를 x_train,y_train데이터에 (학습데이터)에 할당해준다.

def load_data(img_path, number_of_data=900):  # 가위바위보 이미지 개수 총합에 주의하세요.
    img_size=224
    color=3
    #이미지 데이터와 라벨(Moon_jellyfish : 0, mauve_stinger_jellyfish : 1, lions_mane_jellyfish : 2 , compass_jellyfish:3 ,blue_jellyfish:4,barrel_jellyfish:5 ) 데이터를 담을 행렬(matrix) 영역을 생성합니다.
    imgs=np.zeros(number_of_data*img_size*img_size*color,dtype=np.int32).reshape(number_of_data,img_size,img_size,color)
    labels=np.zeros(number_of_data,dtype=np.int32)

    idx=0
    for file in glob.iglob(img_path+'/Moon_jellyfish/*'):#해당디렉토리에는 이미지파일만있고 확장자만 다르기때문에 전체를 불러옴
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=0
        idx=idx+1

    for file in glob.iglob(img_path+'/mauve_stinger_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=1   
        idx=idx+1  
    
    for file in glob.iglob(img_path+'/lions_mane_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=2  
        idx=idx+1
        
    for file in glob.iglob(img_path+'/compass_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=3
        idx=idx+1
        
    for file in glob.iglob(img_path+'/blue_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=4
        idx=idx+1
        
    for file in glob.iglob(img_path+'/barrel_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=5
        idx=idx+1
        
        
    print("학습데이터(x_train)의 이미지 개수는", idx,"입니다.")
    return imgs, labels
image_dir_path = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','Train')
#이미지데이터의 최솟값,최댓값을 확인후 0,1사이의 정규화를 통해 데이터를 정규화 시켜준다.
(x_train, y_train)=load_data(image_dir_path)#load_data함수로imgs, labels를 반환해서 각각 변수에할당
print('최소값:',np.min(x_train), ' 최대값:',np.max(x_train))
x_train_norm = x_train/255.0   # 입력은 0~1 사이의 값으로 정규화

print("x_train shape: {}".format(x_train.shape))
print("y_train shape: {}".format(y_train.shape))
# Out:
# 학습데이터(x_train)의 이미지 개수는 900 입니다.
# 최소값: 0  최대값: 255
# x_train shape: (900, 224, 224, 3)
# y_train shape: (900,)

# %%
#검증데이터  불러오기
#앞서 리사이징 함수를 사용
# Moon_jellyfish 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
img_path2 = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','valid','Moon_jellyfish')
resize_images(img_path2)
print("Moon_jellyfish 이미지 resize 완료!")
print('\n')
img_path2 = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','valid','mauve_stinger_jellyfish')
resize_images(img_path2)
print("mauve_stinger_jellyfish 이미지 resize 완료!")
print('\n')
img_path2 = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','valid','compass_jellyfish')
resize_images(img_path2)
print("lions_mane_jellyfish 이미지 resize 완료!")
print('\n')
img_path2 = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','valid','lions_mane_jellyfish')
resize_images(img_path2)
print("lions_mane_jellyfish 이미지 resize 완료!")
print('\n')
img_path2 = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','valid','blue_jellyfish')
resize_images(img_path2)
print("blue_jellyfish 이미지 resize 완료!")
print('\n')
img_path2= os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','valid','barrel_jellyfish')
resize_images(img_path2)
print("barrel_jellyfish 이미지 resize 완료!")
print('\n')

def load_data(img_path2, number_of_data=39):  # 가위바위보 이미지 개수 총합에 주의하세요.
    img_size=224
    color=3
    #이미지 데이터와 라벨(Moon_jellyfish : 0, mauve_stinger_jellyfish : 1, lions_mane_jellyfish : 2 , compass_jellyfish:3 ,blue_jellyfish:4,barrel_jellyfish:5 ) 데이터를 담을 행렬(matrix) 영역을 생성합니다.
    imgs=np.zeros(number_of_data*img_size*img_size*color,dtype=np.int32).reshape(number_of_data,img_size,img_size,color)
    labels=np.zeros(number_of_data,dtype=np.int32)

    idx=0
    for file in glob.iglob(img_path2+'/Moon_jellyfish/*'):#해당디렉토리에는 이미지파일만있고 확장자만 다르기때문에 전체를 불러옴
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=0
        idx=idx+1

    for file in glob.iglob(img_path2+'/mauve_stinger_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=1   
        idx=idx+1  
    
    for file in glob.iglob(img_path2+'/lions_mane_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=2  
        idx=idx+1
        
    for file in glob.iglob(img_path2+'/compass_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=3
        idx=idx+1
        
    for file in glob.iglob(img_path2+'/blue_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=4
        idx=idx+1
        
    for file in glob.iglob(img_path2+'/barrel_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=5
        idx=idx+1
        
        
    print("학습데이터(x_val)의 이미지 개수는", idx,"입니다.")
    return imgs, labels
image_dir_path2= os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','valid')
#이미지데이터의 최솟값,최댓값을 확인후 0,1사이의 정규화를 통해 데이터를 정규화 시켜준다.
(x_val, y_val)=load_data(image_dir_path2)#load_data함수로imgs, labels를 반환해서 각각 변수에할당
print('최소값:',np.min(x_val), ' 최대값:',np.max(x_val))
x_val_norm = x_val/255.0   # 입력은 0~1 사이의 값으로 정규화

print("x_val shape: {}".format(x_val.shape))
print("y_val shape: {}".format(y_val.shape))
# Out:
# 6  images to be resized.
# 6  images resized.
# Moon_jellyfish 이미지 resize 완료!
#
#
# 7  images to be resized.
# 7  images resized.
# mauve_stinger_jellyfish 이미지 resize 완료!
#
#
# 7  images to be resized.
# 7  images resized.
# lions_mane_jellyfish 이미지 resize 완료!
#
#
# 7  images to be resized.
# 7  images resized.
# lions_mane_jellyfish 이미지 resize 완료!
#
#
# 7  images to be resized.
# 7  images resized.
# blue_jellyfish 이미지 resize 완료!
#
#
# 5  images to be resized.
# 5  images resized.
# barrel_jellyfish 이미지 resize 완료!
#
#
# 학습데이터(x_val)의 이미지 개수는 39 입니다.
# 최소값: 0  최대값: 255
# x_val shape: (39, 224, 224, 3)
# y_val shape: (39,)

# %%
#시험데이터  불러오기
#앞서 리사이징 함수를 사용
# Moon_jellyfish 이미지가 저장된 디렉토리 아래의 모든 jpg 파일을 읽어들여서
img_path3 = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','test','Moon_jellyfish')
resize_images(img_path3)
print("Moon_jellyfish 이미지 resize 완료!")
print('\n')
img_path3 = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','test','mauve_stinger_jellyfish')
resize_images(img_path3)
print("mauve_stinger_jellyfish 이미지 resize 완료!")
print('\n')
img_path3 = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','test','compass_jellyfish')
resize_images(img_path3)
print("lions_mane_jellyfish 이미지 resize 완료!")
print('\n')
img_path3 = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','test','lions_mane_jellyfish')
resize_images(img_path3)
print("lions_mane_jellyfish 이미지 resize 완료!")
print('\n')
img_path3 = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','test','blue_jellyfish')
resize_images(img_path3)
print("blue_jellyfish 이미지 resize 완료!")
print('\n')
img_path3 = os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','test','barrel_jellyfish')
resize_images(img_path3)
print("barrel_jellyfish 이미지 resize 완료!")
print('\n')

def load_data(img_path3, number_of_data=40):  # 가위바위보 이미지 개수 총합에 주의하세요.
    img_size=224
    color=3
    #이미지 데이터와 라벨(Moon_jellyfish : 0, mauve_stinger_jellyfish : 1, lions_mane_jellyfish : 2 , compass_jellyfish:3 ,blue_jellyfish:4,barrel_jellyfish:5 ) 데이터를 담을 행렬(matrix) 영역을 생성합니다.
    imgs=np.zeros(number_of_data*img_size*img_size*color,dtype=np.int32).reshape(number_of_data,img_size,img_size,color)
    labels=np.zeros(number_of_data,dtype=np.int32)

    idx=0
    for file in glob.iglob(img_path3+'/Moon_jellyfish/*'):#해당디렉토리에는 이미지파일만있고 확장자만 다르기때문에 전체를 불러옴
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=0
        idx=idx+1

    for file in glob.iglob(img_path3+'/mauve_stinger_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=1   
        idx=idx+1  
    
    for file in glob.iglob(img_path3+'/lions_mane_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=2  
        idx=idx+1
        
    for file in glob.iglob(img_path3+'/compass_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=3
        idx=idx+1
        
    for file in glob.iglob(img_path3+'/blue_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=4
        idx=idx+1
        
    for file in glob.iglob(img_path3+'/barrel_jellyfish/*'):
        img = np.array(Image.open(file),dtype=np.int32)
        imgs[idx,:,:,:]=img    # 데이터 영역에 이미지 행렬을 복사
        labels[idx]=5
        idx=idx+1
        
        
    print("학습데이터(x_test)의 이미지 개수는", idx,"입니다.")
    return imgs, labels
image_dir_path3= os.path.join(os.getenv('HOME'), 'aiffel', 'jellyfish', 'Train_Test_Valid','test')
#이미지데이터의 최솟값,최댓값을 확인후 0,1사이의 정규화를 통해 데이터를 정규화 시켜준다.
(x_test, y_test)=load_data(image_dir_path3)#load_data함수로imgs, labels를 반환해서 각각 변수에할당
print('최소값:',np.min(x_test), ' 최대값:',np.max(x_test))
x_test_norm = x_test/255.0   # 입력은 0~1 사이의 값으로 정규화

print("x_test shape: {}".format(x_test.shape))
print("y_test shape: {}".format(y_test.shape))
# Out:
# 6  images to be resized.
# 6  images resized.
# Moon_jellyfish 이미지 resize 완료!
#
#
# 7  images to be resized.
# 7  images resized.
# mauve_stinger_jellyfish 이미지 resize 완료!
#
#
# 7  images to be resized.
# 7  images resized.
# lions_mane_jellyfish 이미지 resize 완료!
#
#
# 8  images to be resized.
# 8  images resized.
# lions_mane_jellyfish 이미지 resize 완료!
#
#
# 7  images to be resized.
# 7  images resized.
# blue_jellyfish 이미지 resize 완료!
#
#
# 5  images to be resized.
# 5  images resized.
# barrel_jellyfish 이미지 resize 완료!
#
#
# 학습데이터(x_test)의 이미지 개수는 40 입니다.
# 최소값: 0  최대값: 255
# x_test shape: (40, 224, 224, 3)
# y_test shape: (40,)

# %%
# 레이블을 범주형 카테고리로 가능
# def load_data(img_path, number_of_data=900):
#     img_size = 224
#     color = 3
#     # 이미지 데이터를 담을 배열을 생성합니다.
#     imgs = np.zeros((number_of_data, img_size, img_size, color), dtype=np.int32)
#     # 라벨 데이터를 담을 배열을 생성합니다. 빈 배열로 초기화됩니다.
#     labels = np.empty(number_of_data, dtype=object)  # dtype을 object로 변경

#     idx = 0
#     for file in glob.iglob(img_path + '/Moon_jellyfish/*'):
#         img = np.array(Image.open(file), dtype=np.int32)
#         imgs[idx] = img    # 데이터 영역에 이미지 행렬을 복사
#         labels[idx] = 'Moon_jellyfish'  # 레이블을 문자열로 저장
#         idx += 1

#     # ... [다른 카테고리에 대한 코드 생략] ...

#     return imgs, labels

# # 이미지 데이터 로드
# image_dir_path = os.getenv('HOME') + '/aiffel/jellyfish/Train_Test_Valid/Train'
# (x_train, y_train) = load_data(image_dir_path)

# %%
plt.imshow(x_train[0])
print('라벨: ', y_train[0])
# Out:
# 라벨:  0

# %%
plt.imshow(x_val[0])
print('라벨: ', y_val[0])
# Out:
# 라벨:  0

# %%
plt.imshow(x_test[0])
print('라벨: ', y_test[0])
# Out:
# 라벨:  0

# %%
import matplotlib.pyplot as plt

# x_train에 로드된 이미지와 y_train에 할당된 라벨을 출력합니다.
for i in range(3):  # 5 범위를 설정하여 총 3개의 데이터를 가져옵니다.
    plt.imshow(x_train[i])
    plt.title(f'Label: {y_train[i]}')  # 라벨을 제목으로 표시합니다.
    plt.show()  # 현재의 이미지를 화면에 표시합니다.
#데이터셋이 섞이지않아 차례대로인 0인레이블값만 이미지로 불러온다.

# %%
import numpy as np

# x_train과 y_train을 섞기 전에 두 데이터셋의 순서를 동일하게 유지하기 위해 인덱스를 생성합니다.
indices = np.arange(x_train.shape[0])
# 인덱스를 섞습니다.
np.random.shuffle(indices)

# 인덱스를 사용하여 데이터셋을 섞습니다.
x_train = x_train[indices]
y_train = y_train[indices]

# 섞인 데이터를 확인합니다.
for i in range(6):
    plt.imshow(x_train[i])
    plt.title(f'Label: {y_train[i]}')
    plt.show()

# %%
# #배치사이즈 설정
# BATCH_SIZE = 32
# # SHUFFLE_BUFFER_SIZE = 1000
# #데이터 형상확인
# train_batches = x_train.batch(BATCH_SIZE)
# validation_batches = validation.batch(BATCH_SIZE)
# test_batches = test.batch(BATCH_SIZE)

# for image_batch, label_batch in train_batches.take(1):
#     break

# image_batch.shape, label_batch.shape

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from tensorflow.keras.layers import Flatten, Dense, Dropout, Conv2D, MaxPooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import BatchNormalization
from keras.callbacks import EarlyStopping,ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical

# #각층에 활성화함수로relu를 쓰기때문에 가중치 초깃값을 he초깃값사용
# model=tf.keras.models.Sequential()
# model.add(tf.keras.layers.Conv2D(32, (3,3),  activation='relu' , kernel_initializer='he_normal',input_shape=(224,224,3)))
# model.add(tf.keras.layers.MaxPool2D(2,2))
# model.add(tf.keras.layers.Dropout(0.2))
# # model.add(Dropout(0.25))# Dropout 추가 # 드롭아웃을 합성곱층마다 실행했더니 오히려 정확도가 떨어져서 값을 조정해도 나아지지않아 처음층의 드롭아웃은 안하기로함.
# model.add(tf.keras.layers.Conv2D(64, (3,3), activation='relu' ,kernel_initializer='he_normal'))
# model.add(keras.layers.MaxPool2D(2,2))
# # model.add(tf.keras.layers.BatchNormalization())
# model.add(tf.keras.layers.Dropout(0.2))
# # model.add(keras.layers.Activation('relu'))
# # model.add(keras.layers.MaxPooling2D((2,2)))
# # model.add(Dropout(0.25)) # Dropout 추가
# # model.add(tf.keras.layers.Conv2D(128, (3,3), activation='relu',kernel_initializer='he_normal',kernel_regularizer='l2'))
# # model.add(tf.keras.layers.MaxPooling2D((2,2)))
# # model.add(tf.keras.layers.Dropout(0.2))
# # #model.add(Dropout(0.25)) # Dropout 추가
# # model.add(tf.keras.layers.Conv2D(128, (3,3), activation='relu',kernel_initializer='he_normal',kernel_regularizer='l2'))
# # model.add(tf.keras.layers.MaxPooling2D((2,2)))
# # model.add(tf.keras.layers.Dropout(0.2))
# # # # model.add(BatchNormalization())
# # # # model.add(keras.layers.Activation('relu'))
# # model.add(keras.layers.MaxPooling2D((2,2)))

# model.add(tf.keras.layers.Flatten())
# # model.add(tf.keras.layers.Dense(128, activation='relu',kernel_initializer='he_normal',kernel_regularizer='l2'))
# # model.add(tf.keras.layers.BatchNormalization())#배치정규화를 시키는 이유가 드롭아웃에 대한 의존성을 낮추기위함이라 바로 드롭아웃을 쓰거나 높게 설정하면 오히려 학습을 제대로못해서 성능저하가올수있다.
# # model.add(Dropout(0.5))

# model.add(tf.keras.layers.Dense(64, activation='relu',kernel_initializer='he_normal',kernel_regularizer='l2'))
# model.add(tf.keras.layers.BatchNormalization())
# # model.add(tf.keras.layers.Dense(32, activation='relu',kernel_initializer='he_normal',kernel_regularizer='l2'))
# # model.add(tf.keras.layers.BatchNormalization())
# # model.add(keras.layers.Dense(256, activation='relu',kernel_initializer='he_normal'))
# # model.add(BatchNormalization())
# # model.add(keras.layers.Activation('relu'))
# # model.add(Dropout(0.3))
# model.add(tf.keras.layers.Dense(3, activation='softmax'))

# %%
# #모델구조 시각화
# from tensorflow.keras import  utils
# utils.plot_model(model,show_shapes=True)

# %%
# early_stopping = EarlyStopping(patience=3, restore_best_weights=True)
# #원핫인코딩된라벨이아닌 정수형라벨이기때문에 sparse_categorical_crossentropy 를 loss funtion으로 사용
# model.compile(optimizer='adam',
#               loss='sparse_categorical_crossentropy',
#               metrics=['accuracy'])

# %%
# history = model.fit(x_train, y_train,
#                     epochs=10,
#                     validation_data=(x_val, y_val))

# %%
# ## 정확도 그래프
# plt.figure(figsize=(12, 4))
# plt.subplot(1, 2, 1)
# plt.plot(history.history['accuracy'], 'b-', label='Train accuracy')
# plt.plot(history.history['val_accuracy'], 'r-', label='val accuracy')
# plt.title('Accuracy')
# plt.xlabel('Epoch')
# plt.legend()

# # 손실 그래프
# plt.subplot(1, 2, 2)
# plt.plot(history.history['loss'], 'b-', label='Train loss')
# plt.plot(history.history['val_loss'], 'r-', label='val loss')
# plt.title('Loss')
# plt.xlabel('Epoch')
# plt.legend()

# plt.show()

# %%
#진단할 resnet모델링
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, BatchNormalization, ReLU, Add
from tensorflow.keras.initializers import HeNormal

def conv2d_bn(x, filters, kernel_size, strides, kernel_initializer, kernel_regularizer):
    x = Conv2D(filters, kernel_size, strides=strides, padding='same', 
               kernel_initializer=kernel_initializer,
               kernel_regularizer=kernel_regularizer)(x)
    x = BatchNormalization()(x)
    return x

def conv2d_bn_relu(x, filters, kernel_size, strides, kernel_initializer, kernel_regularizer):
    x = conv2d_bn(x, filters, kernel_size, strides, kernel_initializer, kernel_regularizer)
    x = Activation('relu')(x)
    return x

# ResidualBlock 함수를 정의합니다.
def ResidualBlock(x, filters, kernel_size, kernel_initializer, kernel_regularizer, downsample=False):
#(x, filters, kernel_size, kernel_initializer,  downsample=False):
    shortcut = x
    if downsample:
        shortcut = conv2d_bn(x, filters, kernel_size=1, strides=2, kernel_initializer=kernel_initializer, kernel_regularizer=kernel_regularizer)
        strides = 2
    else:
        strides = 1

#     x = conv2d_bn_relu(x, filters, kernel_size, strides=strides, kernel_initializer=kernel_initializer)
    x = conv2d_bn_relu(x, filters, kernel_size, strides=strides, kernel_initializer=kernel_initializer, kernel_regularizer=kernel_regularizer)
#     x = conv2d_bn(x, filters, kernel_size, strides=1, kernel_initializer=kernel_initializer)
    x = conv2d_bn(x, filters, kernel_size, strides=1, kernel_initializer=kernel_initializer, kernel_regularizer=kernel_regularizer)

    # Add() 레이어를 사용하여 shortcut connection을 구현합니다.
    out = Add()([shortcut, x])
    out = Activation('relu')(out)
    return out

# %%
#resnet모델만들기
import tensorflow as tf
from tensorflow.keras.layers import Input, AveragePooling2D,Flatten,Activation
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
def ResNet18(classes, input_shape):
    inputs = Input(shape=input_shape)
#     conv1 = Conv2D(64, (7,7), strides=2, padding='same', activation='relu', kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(64, (7,7), strides=2, padding='same', activation='relu', kernel_initializer='he_normal', kernel_regularizer=l2(0.01))(inputs)
    
    max_pooling = MaxPooling2D(3, strides=2, padding='same')(conv1)
    
    conv2_x = ResidualBlock(max_pooling, 64, kernel_size=(2,2), kernel_initializer='he_normal', kernel_regularizer=l2(0.01), downsample=False)
    conv2_x = ResidualBlock(conv2_x, 64, kernel_size=(2,2), kernel_initializer='he_normal', kernel_regularizer=l2(0.01), downsample=False)

#     conv2_x = ResidualBlock(max_pooling, 64, kernel_size=(3,3), kernel_initializer='he_normal', downsample=False)
#     conv2_x = ResidualBlock(conv2_x, 64, kernel_size=(3,3), kernel_initializer='he_normal',  downsample=False)
    
    conv3_x = ResidualBlock(conv2_x, 128, kernel_size=(2,2), kernel_initializer='he_normal', kernel_regularizer=l2(0.01), downsample=True)
    conv3_x = ResidualBlock(conv3_x, 128, kernel_size=(2,2), kernel_initializer='he_normal', kernel_regularizer=l2(0.01), downsample=False)

#     conv3_x = ResidualBlock(conv2_x, 128, kernel_size=(3,3), kernel_initializer='he_normal',  downsample=True)
#     conv3_x = ResidualBlock(conv3_x, 128, kernel_size=(3,3), kernel_initializer='he_normal', downsample=False)
    
    conv4_x = ResidualBlock(conv3_x, 256, kernel_size=(2,2), kernel_initializer='he_normal', kernel_regularizer=l2(0.01), downsample=True)
    conv4_x = ResidualBlock(conv4_x, 256, kernel_size=(2,2), kernel_initializer='he_normal', kernel_regularizer=l2(0.01), downsample=False)

#     conv4_x = ResidualBlock(conv3_x, 256, kernel_size=(3,3), kernel_initializer='he_normal', downsample=True)
#     conv4_x = ResidualBlock(conv4_x, 256, kernel_size=(3,3), kernel_initializer='he_normal',  downsample=False)
    
    conv5_x = ResidualBlock(conv4_x, 512, kernel_size=(2,2), kernel_initializer='he_normal', kernel_regularizer=l2(0.01), downsample=True)
    conv5_x = ResidualBlock(conv5_x, 512, kernel_size=(2,2), kernel_initializer='he_normal', kernel_regularizer=l2(0.01), downsample=False)

#     conv5_x = ResidualBlock(conv4_x, 512, kernel_size=(3,3), kernel_initializer='he_normal', downsample=True)
#     conv5_x = ResidualBlock(conv5_x, 512, kernel_size=(3,3), kernel_initializer='he_normal',  downsample=False)
    
    x = GlobalAveragePooling2D()(conv5_x)
    x = Flatten()(x)
    x = Dense(64, activation='relu', kernel_initializer='he_normal', kernel_regularizer=l2(0.01))(x)
    x = Dense(32, activation='relu', kernel_initializer='he_normal', kernel_regularizer=l2(0.01))(x)
    out_layer = Dense(units=classes, activation='softmax')(x)
    
    model = Model(inputs=inputs, outputs=out_layer)
    return model

# %%
#교차검증및 데이터증강
from sklearn.model_selection import KFold
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from tensorflow.keras.optimizers import Adam,RMSprop
from tensorflow. keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(patience=5, restore_best_weights=True)

# 전체 데이터셋 결합
x_full = np.concatenate((x_train, x_val))
# y_full = to_categorical(np.concatenate((y_train, y_val)))
# print(y_full.shape)
one_hot_y_train = to_categorical(y_train)
one_hot_y_val = to_categorical(y_val)
# y_full = to_categorical(y_full)
y_full = np.concatenate((one_hot_y_train, one_hot_y_val))
print(y_full.shape)
# # 데이터 증강 설정
data_augmentation = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# k-겹 교차 검증 설정
k = 5
kf = KFold(n_splits=k, shuffle=True, random_state=42)

# 교차 검증 수행
fold_perfomance = []

from tensorflow.keras.mixed_precision import experimental as mixed_precision#GPU메모리가 부족하여 16비트 정밀도 사용: 가능하다면 16비트 부동소수점(float16) 연산을 사용하여 메모리 사용량을 크게 줄일 수 있습니다. 최신의 많은 GPU는 16비트 연산을 지원하며, 이를 통해 메모리 사용량과 연산 시간을 줄일 수 있습니다.
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_policy(policy)


for train_index, val_index in kf.split(x_full):
#     # 학습 데이터와 검증 데이터 분할
    x_train_fold, x_val_fold = x_full[train_index], x_full[val_index]
    y_train_fold, y_val_fold = y_full[train_index], y_full[val_index]
    print(y_train_fold.shape)
    print(y_val_fold.shape)

    
#     # 데이터 증강 적용
    
    train_datagen = data_augmentation.flow(x_train_fold, y_train_fold, batch_size=16)
    val_datagen = ImageDataGenerator().flow(x_val_fold, y_val_fold, batch_size=16)
    next(train_datagen)
    next(val_datagen)
    x_batch, y_batch = next(train_datagen)
    print(x_batch.shape)
    print(y_batch.shape)

 # 모델을 정의합니다.
    with tf.device('/GPU:0'):
        model = ResNet18(classes=6, input_shape=(224, 224, 3))
    
    # 모델을 컴파일합니다.
#평가지표 설정(변수할당)
        METRICS = [
            'accuracy',
            tf.keras.metrics.Precision(name='precision'),
            tf.keras.metrics.Recall(name='recall')
        ]
    # 학습률 설정
        learning_rate = 0.0001#0.0001

    # 옵티마이저 생성
        optimizer = RMSprop(learning_rate=learning_rate)
        model.compile(
            optimizer=optimizer,
            loss='categorical_crossentropy',
            metrics=METRICS
        )
   # 모델을 학습합니다.
    with tf.device('/GPU:0'):
        model.fit(
            x_train_fold, 
            y_train_fold,
            batch_size=16,
            epochs=20, 
            callbacks=[early_stopping],
            validation_data=(x_val_fold,y_val_fold))
        #batch_size=16,
            #epochs=20, 

   
    
    # 검증 데이터에 대한 성능 평가
performance = model.evaluate(x_val_fold,y_val_fold)
fold_perfomance.append(performance)

# 평균 성능 계산
average_performance = np.mean(fold_perfomance, axis=0)
# Out:
# (939, 6)
# (751, 6)
# (188, 6)
# (16, 224, 224, 3)
# (16, 6)
# WARNING:tensorflow:tf.keras.mixed_precision.experimental.LossScaleOptimizer is deprecated. Please use tf.keras.mixed_precision.LossScaleOptimizer instead. Note that the non-experimental LossScaleOptimizer does not take a DynamicLossScale but instead takes the dynamic configuration directly in the constructor. For example:
#   opt = tf.keras.mixed_precision.LossScaleOptimizer(opt)
#
# Epoch 1/20
# 47/47 [==============================] - 9s 59ms/step - loss: 95.1938 - accuracy: 0.3222 - precision: 0.3913 - recall: 0.0719 - val_loss: 94.2622 - val_accuracy: 0.2128 - val_precision: 0.2114 - val_recall: 0.1968
# Epoch 2/20
# 47/47 [==============================] - 2s 42ms/step - loss: 87.3824 - accuracy: 0.5233 - precision: 0.6634 - recall: 0.1811 - val_loss: 85.2721 - val_accuracy: 0.3085 - val_precision: 0.3333 - val_recall: 0.2500
# Epoch 3/20
# 47/47 [==============================] - 2s 40ms/step - loss: 80.5175 - accuracy: 0.6192 - precision: 0.7645 - recall: 0.3502 - val_loss: 78.5310 - val_accuracy: 0.3883 - val_precision: 0.3931 - val_recall: 0.3032
# Epoch 4/20
# 47/47 [==============================] - 2s 40ms/step - loss: 74.5292 - accuracy: 0.6818 - precision: 0.8044 - recall: 0.4874 - val_loss: 72.2058 - val_accuracy: 0.5479 - val_precision: 0.6667 - val_recall: 0.3511
# Epoch 5/20
# 47/47 [==============================] - 2s 40ms/step - loss: 69.2365 - accuracy: 0.7550 - precision: 0.8556 - recall: 0.6232 - val_loss: 67.3106 - val_accuracy: 0.5160 - val_precision: 0.6698 - val_recall: 0.3777
# Epoch 6/20
# 47/47 [==============================] - 2s 41ms/step - loss: 64.3604 - accuracy: 0.8176 - precision: 0.8712 - recall: 0.7297 - val_loss: 62.5404 - val_accuracy: 0.6383 - val_precision: 0.7197 - val_recall: 0.5053
# Epoch 7/20
# 47/47 [==============================] - 2s 41ms/step - loss: 60.1623 - accuracy: 0.8362 - precision: 0.8932 - recall: 0.7683 - val_loss: 58.9154 - val_accuracy: 0.5957 - val_precision: 0.6800 - val_recall: 0.5426
# Epoch 8/20
# Epoch 12/20
# 47/47 [==============================] - 2s 40ms/step - loss: 41.3652 - accuracy: 0.9401 - precision: 0.9496 - recall: 0.9281 - val_loss: 41.1910 - val_accuracy: 0.5904 - val_precision: 0.6522 - val_recall: 0.4787
# Epoch 13/20
# 47/47 [==============================] - 2s 39ms/step - loss: 39.1292 - accuracy: 0.9481 - precision: 0.9575 - recall: 0.9308 - val_loss: 39.1685 - val_accuracy: 0.5585 - val_precision: 0.6277 - val_recall: 0.4574
# Epoch 14/20
# 47/47 [==============================] - 2s 40ms/step - loss: 36.8900 - accuracy: 0.9654 - precision: 0.9716 - recall: 0.9561 - val_loss: 36.9059 - val_accuracy: 0.5851 - val_precision: 0.6622 - val_recall: 0.5213
# Epoch 15/20
# 47/47 [==============================] - 2s 40ms/step - loss: 34.8121 - accuracy: 0.9574 - precision: 0.9648 - recall: 0.9494 - val_loss: 36.3432 - val_accuracy: 0.3936 - val_precision: 0.3929 - val_recall: 0.3511
# Epoch 16/20
# 47/47 [==============================] - 2s 39ms/step - loss: 33.0073 - accuracy: 0.9547 - precision: 0.9647 - recall: 0.9454 - val_loss: 33.4921 - val_accuracy: 0.5745 - val_precision: 0.6410 - val_recall: 0.5319
# Epoch 17/20
# 47/47 [==============================] - 2s 40ms/step - loss: 31.3541 - accuracy: 0.9654 - precision: 0.9742 - recall: 0.9561 - val_loss: 32.2574 - val_accuracy: 0.4521 - val_precision: 0.4935 - val_recall: 0.4043
# Epoch 18/20
# 47/47 [==============================] - 2s 40ms/step - loss: 29.7298 - accuracy: 0.9601 - precision: 0.9625 - recall: 0.9574 - val_loss: 30.3546 - val_accuracy: 0.5745 - val_precision: 0.6265 - val_recall: 0.5532
# Epoch 19/20
# 47/47 [==============================] - 2s 40ms/step - loss: 28.2114 - accuracy: 0.9747 - precision: 0.9798 - recall: 0.9707 - val_loss: 28.3979 - val_accuracy: 0.6383 - val_precision: 0.7500 - val_recall: 0.5266
# Epoch 20/20
# 47/47 [==============================] - 2s 40ms/step - loss: 26.7052 - accuracy: 0.9601 - precision: 0.9638 - recall: 0.9561 - val_loss: 27.4222 - val_accuracy: 0.5479 - val_precision: 0.6194 - val_recall: 0.5106
# (751, 6)
# (188, 6)
# (16, 224, 224, 3)
# (16, 6)
# WARNING:tensorflow:tf.keras.mixed_precision.experimental.LossScaleOptimizer is deprecated. Please use tf.keras.mixed_precision.LossScaleOptimizer instead. Note that the non-experimental LossScaleOptimizer does not take a DynamicLossScale but instead takes the dynamic configuration directly in the constructor. For example:
#   opt = tf.keras.mixed_precision.LossScaleOptimizer(opt)
#
# Epoch 1/20
# 47/47 [==============================] - 8s 58ms/step - loss: 94.4812 - accuracy: 0.3382 - precision: 0.5204 - recall: 0.0679 - val_loss: 92.7576 - val_accuracy: 0.2394 - val_precision: 0.2847 - val_recall: 0.2181
# Epoch 2/20
# 47/47 [==============================] - 2s 40ms/step - loss: 86.2734 - accuracy: 0.5353 - precision: 0.7066 - recall: 0.2277 - val_loss: 83.1523 - val_accuracy: 0.3032 - val_precision: 0.3875 - val_recall: 0.1649
# 47/47 [==============================] - 2s 40ms/step - loss: 34.8155 - accuracy: 0.9614 - precision: 0.9701 - recall: 0.9521 - val_loss: 34.9089 - val_accuracy: 0.5691 - val_precision: 0.6242 - val_recall: 0.5213
# Epoch 16/20
# 47/47 [==============================] - 2s 40ms/step - loss: 32.8156 - accuracy: 0.9627 - precision: 0.9689 - recall: 0.9547 - val_loss: 33.5199 - val_accuracy: 0.4574 - val_precision: 0.5098 - val_recall: 0.4149
# Epoch 17/20
# 47/47 [==============================] - 2s 40ms/step - loss: 31.1474 - accuracy: 0.9534 - precision: 0.9658 - recall: 0.9387 - val_loss: 31.8797 - val_accuracy: 0.5106 - val_precision: 0.5769 - val_recall: 0.4787
# Epoch 18/20
# 47/47 [==============================] - 2s 40ms/step - loss: 29.6040 - accuracy: 0.9720 - precision: 0.9785 - recall: 0.9680 - val_loss: 30.1653 - val_accuracy: 0.4574 - val_precision: 0.5168 - val_recall: 0.4096
# Epoch 19/20
# 47/47 [==============================] - 2s 40ms/step - loss: 28.0723 - accuracy: 0.9627 - precision: 0.9691 - recall: 0.9601 - val_loss: 29.0759 - val_accuracy: 0.5479 - val_precision: 0.5906 - val_recall: 0.5372
# Epoch 20/20
# 47/47 [==============================] - 2s 40ms/step - loss: 26.7885 - accuracy: 0.9561 - precision: 0.9624 - recall: 0.9534 - val_loss: 29.2628 - val_accuracy: 0.3989 - val_precision: 0.4114 - val_recall: 0.3830
# (751, 6)
# (188, 6)
# (16, 224, 224, 3)
# (16, 6)
# WARNING:tensorflow:tf.keras.mixed_precision.experimental.LossScaleOptimizer is deprecated. Please use tf.keras.mixed_precision.LossScaleOptimizer instead. Note that the non-experimental LossScaleOptimizer does not take a DynamicLossScale but instead takes the dynamic configuration directly in the constructor. For example:
#   opt = tf.keras.mixed_precision.LossScaleOptimizer(opt)
#
# Epoch 1/20
# 47/47 [==============================] - 8s 58ms/step - loss: 94.3698 - accuracy: 0.3808 - precision: 0.5857 - recall: 0.1092 - val_loss: 94.4440 - val_accuracy: 0.2926 - val_precision: 0.3068 - val_recall: 0.2872
# Epoch 2/20
# 47/47 [==============================] - 2s 40ms/step - loss: 86.1549 - accuracy: 0.5353 - precision: 0.7211 - recall: 0.2410 - val_loss: 85.4925 - val_accuracy: 0.2128 - val_precision: 0.2222 - val_recall: 0.2021
# Epoch 3/20
# 47/47 [==============================] - 2s 40ms/step - loss: 79.2361 - accuracy: 0.6072 - precision: 0.7749 - recall: 0.4035 - val_loss: 76.6243 - val_accuracy: 0.4468 - val_precision: 0.4615 - val_recall: 0.2553
# Epoch 4/20
# 47/47 [==============================] - 2s 40ms/step - loss: 73.1653 - accuracy: 0.6724 - precision: 0.8000 - recall: 0.4953 - val_loss: 71.0400 - val_accuracy: 0.4628 - val_precision: 0.5169 - val_recall: 0.3245
# Epoch 5/20
# 47/47 [==============================] - 2s 39ms/step - loss: 67.8413 - accuracy: 0.7270 - precision: 0.8375 - recall: 0.5832 - val_loss: 66.0560 - val_accuracy: 0.5851 - val_precision: 0.6698 - val_recall: 0.3777
# Epoch 6/20
# Epoch 19/20
# 47/47 [==============================] - 2s 40ms/step - loss: 29.1987 - accuracy: 0.9401 - precision: 0.9470 - recall: 0.9281 - val_loss: 29.7687 - val_accuracy: 0.5691 - val_precision: 0.6154 - val_recall: 0.5532
# Epoch 20/20
# 47/47 [==============================] - 2s 40ms/step - loss: 27.8881 - accuracy: 0.9707 - precision: 0.9745 - recall: 0.9680 - val_loss: 28.1312 - val_accuracy: 0.6170 - val_precision: 0.6790 - val_recall: 0.5851
# (752, 6)
# (187, 6)
# (16, 224, 224, 3)
# (16, 6)
# WARNING:tensorflow:tf.keras.mixed_precision.experimental.LossScaleOptimizer is deprecated. Please use tf.keras.mixed_precision.LossScaleOptimizer instead. Note that the non-experimental LossScaleOptimizer does not take a DynamicLossScale but instead takes the dynamic configuration directly in the constructor. For example:
#   opt = tf.keras.mixed_precision.LossScaleOptimizer(opt)
#
# Epoch 1/20
# 47/47 [==============================] - 8s 56ms/step - loss: 95.0967 - accuracy: 0.3870 - precision: 0.5059 - recall: 0.1144 - val_loss: 95.4086 - val_accuracy: 0.1925 - val_precision: 0.1854 - val_recall: 0.1765
# Epoch 2/20
# 47/47 [==============================] - 2s 39ms/step - loss: 87.4117 - accuracy: 0.5652 - precision: 0.7314 - recall: 0.2753 - val_loss: 85.4502 - val_accuracy: 0.1872 - val_precision: 0.1620 - val_recall: 0.1230
# Epoch 3/20
# 47/47 [==============================] - 2s 38ms/step - loss: 80.6688 - accuracy: 0.6689 - precision: 0.7976 - recall: 0.4508 - val_loss: 78.9405 - val_accuracy: 0.2513 - val_precision: 0.2636 - val_recall: 0.1818
# Epoch 4/20
# 47/47 [==============================] - 2s 37ms/step - loss: 74.7267 - accuracy: 0.7274 - precision: 0.8385 - recall: 0.5731 - val_loss: 72.3807 - val_accuracy: 0.5882 - val_precision: 0.7500 - val_recall: 0.3529
# Epoch 5/20
# 47/47 [==============================] - 2s 39ms/step - loss: 69.3987 - accuracy: 0.7832 - precision: 0.8682 - recall: 0.7008 - val_loss: 67.8088 - val_accuracy: 0.4385 - val_precision: 0.5610 - val_recall: 0.3690
# Epoch 6/20
# 47/47 [==============================] - 2s 38ms/step - loss: 64.4385 - accuracy: 0.8324 - precision: 0.8948 - recall: 0.7580 - val_loss: 62.9588 - val_accuracy: 0.5348 - val_precision: 0.7373 - val_recall: 0.4652
# Epoch 7/20
# 47/47 [==============================] - 2s 37ms/step - loss: 60.1936 - accuracy: 0.8644 - precision: 0.9074 - recall: 0.8205 - val_loss: 59.1008 - val_accuracy: 0.5668 - val_precision: 0.6585 - val_recall: 0.4332
# Epoch 8/20
# 47/47 [==============================] - 2s 38ms/step - loss: 56.3027 - accuracy: 0.9229 - precision: 0.9445 - recall: 0.8830 - val_loss: 55.1385 - val_accuracy: 0.5936 - val_precision: 0.7719 - val_recall: 0.4706
# Epoch 9/20
# 47/47 [==============================] - 2s 38ms/step - loss: 52.4615 - accuracy: 0.9189 - precision: 0.9415 - recall: 0.8989 - val_loss: 52.1256 - val_accuracy: 0.4599 - val_precision: 0.5067 - val_recall: 0.4064
# Epoch 10/20
# 47/47 [==============================] - 2s 38ms/step - loss: 49.1736 - accuracy: 0.9388 - precision: 0.9534 - recall: 0.9255 - val_loss: 49.3493 - val_accuracy: 0.5134 - val_precision: 0.5247 - val_recall: 0.4545
# Epoch 11/20
# 47/47 [==============================] - 2s 38ms/step - loss: 46.0218 - accuracy: 0.9588 - precision: 0.9700 - recall: 0.9455 - val_loss: 45.4880 - val_accuracy: 0.6310 - val_precision: 0.7357 - val_recall: 0.5508
# Epoch 12/20
# 47/47 [==============================] - 2s 39ms/step - loss: 43.4094 - accuracy: 0.9388 - precision: 0.9525 - recall: 0.9335 - val_loss: 43.6273 - val_accuracy: 0.5401 - val_precision: 0.5749 - val_recall: 0.5134
# Epoch 13/20
# 47/47 [==============================] - 2s 38ms/step - loss: 40.7631 - accuracy: 0.9681 - precision: 0.9783 - recall: 0.9601 - val_loss: 40.5662 - val_accuracy: 0.5775 - val_precision: 0.6714 - val_recall: 0.5027
# Epoch 14/20
# 47/47 [==============================] - 2s 38ms/step - loss: 38.3687 - accuracy: 0.9561 - precision: 0.9610 - recall: 0.9495 - val_loss: 38.6790 - val_accuracy: 0.5080 - val_precision: 0.5380 - val_recall: 0.4545
# Epoch 15/20
# 47/47 [==============================] - 2s 38ms/step - loss: 36.2035 - accuracy: 0.9707 - precision: 0.9772 - recall: 0.9694 - val_loss: 36.6919 - val_accuracy: 0.5882 - val_precision: 0.6599 - val_recall: 0.5187
# Epoch 16/20
# 47/47 [==============================] - 2s 39ms/step - loss: 34.3950 - accuracy: 0.9468 - precision: 0.9530 - recall: 0.9441 - val_loss: 35.1450 - val_accuracy: 0.4545 - val_precision: 0.4903 - val_recall: 0.4064
# Epoch 17/20
# 47/47 [==============================] - 2s 38ms/step - loss: 32.8033 - accuracy: 0.9574 - precision: 0.9637 - recall: 0.9521 - val_loss: 33.5399 - val_accuracy: 0.5455 - val_precision: 0.5988 - val_recall: 0.5187
# Epoch 18/20
# 47/47 [==============================] - 2s 38ms/step - loss: 31.2283 - accuracy: 0.9707 - precision: 0.9785 - recall: 0.9668 - val_loss: 32.8349 - val_accuracy: 0.4118 - val_precision: 0.4217 - val_recall: 0.3743
# Epoch 19/20
# 47/47 [==============================] - 2s 39ms/step - loss: 29.5668 - accuracy: 0.9681 - precision: 0.9719 - recall: 0.9654 - val_loss: 30.5835 - val_accuracy: 0.4920 - val_precision: 0.5263 - val_recall: 0.4278
# Epoch 20/20
# 47/47 [==============================] - 2s 38ms/step - loss: 28.2824 - accuracy: 0.9548 - precision: 0.9596 - recall: 0.9481 - val_loss: 29.9420 - val_accuracy: 0.4759 - val_precision: 0.4800 - val_recall: 0.4492
# 6/6 [==============================] - 0s 17ms/step - loss: 29.9417 - accuracy: 0.4759 - precision: 0.4800 - recall: 0.4492

# %%
# # 모델 가중치 저장
# model.save_weights('model_weights.h5')

# # 새 모델 생성
# new_model = ResNet18(classes=6, input_shape=(224, 224, 3))

# # 저장된 가중치 로드
# new_model.load_weights('model_weights.h5')

# # 새 모델 컴파일
# new_model.compile(
#     optimizer=Adam(learning_rate=0.0001),
#     loss='categorical_crossentropy',
#     metrics=[
#         'accuracy',
#         tf.keras.metrics.Precision(name='precision'),
#         tf.keras.metrics.Recall(name='recall')
#     ]
# )

# # 테스트 데이터로 성능 평가
# test_performance = new_model.evaluate(x_test, y_test)

# print("Test Loss: ", test_performance[0])
# print("Test Accuracy: ", test_performance[1])

# %%
one_hot_y_test = to_categorical(y_test)
test_performance = model.evaluate(x_test, one_hot_y_test)

print("Test Loss: ", test_performance[0])
print("Test Accuracy: ", test_performance[1])
# # 데이터 증강을 적용합니다.
# augmented_data = data_augmentation.flow(x_train, y_train, batch_size=32)

# # 전체 학습 데이터로 모델을 훈련합니다.
# history = model.fit(augmented_data, epochs=10, steps_per_epoch=len(x_train)/32)

# # 테스트 데이터셋으로 모델 평가
# test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=2)

# # 테스트 손실과 테스트 정확도 출력
# print(f"테스트 손실: {test_loss}")
# print(f"테스트 정확도: {test_accuracy}")
# Out:
# 2/2 [==============================] - 0s 12ms/step - loss: 30.1827 - accuracy: 0.3250 - precision: 0.3529 - recall: 0.3000
# Test Loss:  30.182727813720703
# Test Accuracy:  0.32499998807907104

# %%
# # 필요한 라이브러리 임포트
# from tensorflow.keras.utils import to_categorical
# from sklearn.model_selection import KFold
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# import numpy as np
# from tensorflow.keras.optimizers import Adam

# # 전체 데이터셋 결합
# x_full = np.concatenate((x_train, x_val))

# # 레이블을 원-핫 인코딩으로 변환
# y_full = to_categorical(np.concatenate((y_train, y_val)))
# print(y_full.shape)

# # 데이터 증강 설정
# data_augmentation = ImageDataGenerator(
#     rotation_range=20,
#     width_shift_range=0.2,
#     height_shift_range=0.2,
#     zoom_range=0.2,
#     horizontal_flip=True,
#     fill_mode='nearest'
# )

# # k-겹 교차 검증 설정
# k = 5
# kf = KFold(n_splits=k, shuffle=True, random_state=42)

# # 교차 검증 수행
# fold_perfomance = []

# from tensorflow.keras.mixed_precision import experimental as mixed_precision
# policy = mixed_precision.Policy('mixed_float16')
# mixed_precision.set_policy(policy)

# for train_index, val_index in kf.split(x_full):
#     # 학습 데이터와 검증 데이터 분할
#     x_train_fold, x_val_fold = x_full[train_index], x_full[val_index]
    
#     # 레이블을 원-핫 인코딩으로 변환
#     y_train_fold, y_val_fold = to_categorical(y_full[train_index]), to_categorical(y_full[val_index])
#     print(y_train_fold.shape)
#     print(y_val_fold.shape)

#     # 데이터 증강 적용
#     train_datagen = data_augmentation.flow(x_train_fold, y_train_fold, batch_size=16)
#     val_datagen = ImageDataGenerator().flow(x_val_fold, y_val_fold, batch_size=16)

#     # 모델 정의
#     with tf.device('/GPU:0'):
#         model = ResNet18(classes=6, input_shape=(224, 224, 3))
    
#     # 모델 컴파일
#     METRICS = [
#         'accuracy',
#         tf.keras.metrics.Precision(name='precision'),
#         tf.keras.metrics.Recall(name='recall')
#     ]
#     learning_rate = 0.0001
#     optimizer = Adam(learning_rate=learning_rate)
#     model.compile(
#         optimizer=optimizer,
#         loss='categorical_crossentropy',  # 원-핫 인코딩된 레이블에 사용하는 손실 함수
#         metrics=METRICS
#     )

#     # 모델 학습
#     with tf.device('/GPU:0'):
#         model.fit(
#             train_datagen, 
#             epochs=10, 
#             validation_data=val_datagen
#         )

#     # 검증 데이터에 대한 성능 평가
#     performance = model.evaluate(val_datagen)
#     fold_perfomance.append(performance)

# # 평균 성능 계산
# average_performance = np.mean(fold_perfomance, axis=0)
